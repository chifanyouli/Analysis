# %%
import pandas as pd

# %%
df = pd.read_csv("Individual Contributions.csv")
# Out:
# D:\Anaconda-Python\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (32) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head(6)
# Out:
#   committee_id committee_name  report_year report_type        image_number  \
# 0    C00696948    BERNIE 2020         2020          M4  202004209220084024
# 1    C00696948    BERNIE 2020         2020          M4  202004209220083985
# 2    C00696948    BERNIE 2020         2020          M4  202004209220083961
# 3    C00696948    BERNIE 2020         2020          M4  202004209220083933
# 4    C00696948    BERNIE 2020         2020          M4  202004209220083929
# 5    C00696948    BERNIE 2020         2020          M4  202004209220083898
#
#   line_number  transaction_id  file_number  committee_name.1 entity_type  ...  \
# 0         17A        20639506      1402435               NaN         IND  ...
# 1         17A        20631468      1402435               NaN         IND  ...
# 2         17A        20641255      1402435               NaN         IND  ...
# 3         17A        20634601      1402435               NaN         IND  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 484708 entries, 0 to 484707
# Data columns (total 79 columns):
# committee_id                             484708 non-null object
# committee_name                           484708 non-null object
# report_year                              484708 non-null int64
# report_type                              484708 non-null object
# image_number                             484708 non-null int64
# line_number                              484708 non-null object
# transaction_id                           484708 non-null int64
# file_number                              484708 non-null int64
# committee_name.1                         0 non-null float64
# entity_type                              484708 non-null object
# entity_type_desc                         484708 non-null object
# unused_contbr_id                         475873 non-null object
# contributor_prefix                       0 non-null float64
# ...

# %%
pd.set_option('Max_column', 82)
pd.set_option('Max_row', 100)

# %%
df.head(6)
# Out:
#   committee_id committee_name  report_year report_type        image_number  \
# 0    C00696948    BERNIE 2020         2020          M4  202004209220084024
# 1    C00696948    BERNIE 2020         2020          M4  202004209220083985
# 2    C00696948    BERNIE 2020         2020          M4  202004209220083961
# 3    C00696948    BERNIE 2020         2020          M4  202004209220083933
# 4    C00696948    BERNIE 2020         2020          M4  202004209220083929
# 5    C00696948    BERNIE 2020         2020          M4  202004209220083898
#
#   line_number  transaction_id  file_number  committee_name.1 entity_type  \
# 0         17A        20639506      1402435               NaN         IND
# 1         17A        20631468      1402435               NaN         IND
# 2         17A        20641255      1402435               NaN         IND
# 3         17A        20634601      1402435               NaN         IND
# 4         17A        20632540      1402435               NaN         IND
# ...

# %% [markdown]
# ## Step 9
# #### At the same time, it is not necessary in this case but check which column can be <b>primary key</b> and select it with other columns as Step 8 just in case.

# %%
df.nunique()
# Out:
# committee_id                                  1
# committee_name                                1
# report_year                                   1
# report_type                                   1
# image_number                             320194
# line_number                                   1
# transaction_id                           484708
# file_number                                   1
# committee_name.1                              0
# entity_type                                   2
# entity_type_desc                              2
# unused_contbr_id                              1
# contributor_prefix                            0
# contributor_name                         151012
# recipient_committee_type                      1
# recipient_committee_org_type                  0
# recipient_committee_designation               1
# contributor_first_name                    16264
# contributor_middle_name                     351
# contributor_last_name                     60700
# ...

# %%
ds = df[['transaction_id',
         'contribution_receipt_date',
         'contributor_name', 
         'contributor_state',
         'contributor_employer',
         'contributor_occupation',
         'contribution_receipt_amount',
         'contributor_aggregate_ytd']]

# %%
ds.to_csv('Prepared_dataset.csv')

# %% [markdown]
# ## Duplicate Tests

# %% [markdown]
# ### 1. combine name, address, occupation and employer as unique identification

# %%
NoChange = df['contributor_name'] + \
            df['contributor_street_1'] + \
            df['contributor_street_2'] + \
            df['contributor_city'] + \
            df['contributor_state'] + \
            df['contributor_employer'] + \
            df['contributor_occupation']
NoChange.nunique()
# Out:
# 35431

# %% [markdown]
# ### 2. combine name, employer as unique identification

# %%
SameNameNotEmployer = df['contributor_name'] + df['contributor_employer']
SameNameNotEmployer.nunique()
# Out:
# 157484

# %% [markdown]
# ### 3. combine name, occupation as unique identification

# %%
SameNameNotOccupation = df['contributor_name'] + df['contributor_occupation']
SameNameNotOccupation.nunique()
# Out:
# 157801

# %% [markdown]
# ### 4. combine name, address as unique identification

# %%
SameNameNotAddress = df['contributor_name'] + \
                        df['contributor_street_1'] + \
                        df['contributor_street_2'] + \
                        df['contributor_city'] + \
                        df['contributor_state']
SameNameNotAddress.nunique()
# Out:
# 35574
